# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Interactive Shell

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print ("Hello, world")

# %%
# jupyter magic command: list curret directory content
# %ls

# %%
x = 12**2
x/2

# %%
# This is a comment

# %% [markdown]
# ## Variables

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Try this, you get an error
print (var1)

# %% [markdown]
# ## Numbers

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
12
3.14
(-1+2)*3/4**5
x = -5
y = abs(x)
z= 0x14

# %%
print(x,y,z)

# %% [markdown]
# ## Strings

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print ("hello"+"world")    # concatenation
print ("hello"*3)          # repetition
print("hello"[0])         # indexing
print("hello"[-1])        # (from end)
print("hello"[1:4])       # slicing
len("hello")               # size

# %%
print("hello" < "jello")  # comparison
print("e" in "hello")     # search
print("\n etc")          # escape
'single quotes'  
"""triple quotes"""  
r"raw strings"

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
smiles = "C(=N)(N)N.C(=O)(O)O"
print( smiles)

# %%
smiles.find("(O)")

# %%
smiles.find(".")

# %%
smiles.find(".", 10)  #find .  after 10th poition

# %%
smiles.split(".")

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
if "Br" in "Brother":
    print ("contains brother")
email_address = "clin"
if "@" not in email_address:
    email_address += "@brandeis.edu"
print (email_address)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
fo = open('space.txt', 'w')
spacious = "   xyz   "
fo.write(spacious.strip() + '\n')
fo.write (spacious.lstrip() + '\n')
fo.write (spacious.rstrip() + '\n')
fo.close()

# %% [markdown]
# View the file
# [space.txt](space.txt)

# %% [markdown]
# ### Boolean
#
# #### Things that are False
# + The boolean value False
# + The numbers 0 (integer), 0.0 (float) and 0j (complex).
# + The empty string "".
# + he empty list [], empty dictionary {} and empty set set().
#
# #### Things that are True
# + The boolean value True
# + All non-zero numbers.
# + Any string containing at least one character.
# + A non-empty data structure.

# %%
# Logical and and or
ben = input("Ben\'s age ")
chen = input("Chen\'s  age ")
ben = int(ben)
chen = int(chen)
if (ben <= 5 and chen >= 10):
    print ("Ben and Chen")

# Range Test
from datetime import datetime
Time = datetime.now().hour
if (8 <= Time <= 18):
    print ("Office Hour")

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# for example
names = ["Ben", "Chen", "Yaqin"]
for name in names:
    print (name)

# %%
# using break/contunue
for value in [3, 1, 4, 1, 5, 9, 2]:
    print ("Checking", value)
    if value > 8:        
        print ("Exiting for loop")        
        break    
    elif value < 3:        
        print ("Ignoring")       
        continue
    print ("The square is", value**2)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
range(5))

# %%
list(range(5))

# %%
range(5,10)

# %%
list(range(5,10))

# %%
range(0, 10, 2)

# %%
list(range(0,10,2))

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a = list(range(5))
print(a)
a.append(5)
print(a)
a.pop()
print(a)
a.insert(0, 42)
print(a)
a.pop(0)     # pop out the last item added
print(a)
a.reverse()
print(a)
a.sort()
print(a)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# +,extend and append
a = [1,2]
b=[3,4]
c=a+b
print(c)
a.extend(b)
print(a)
a.append(b)
print(a)
# Explian the difference between extend and append

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Solution 1
orgData = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J'] 
newData = []
n = 0
for item in orgData:
    n += 1
    if n % 2:
        newData.append(item)
    
print(newData)

# %%
# Solution 2
orgData = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J'] 
newData = []
for i, item in enumerate(orgData):
    if i % 2 == 0 :
        newData.append(item)

# %%
 # Solution 3
orgData = ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J'] 
newData = [item for i, item in enumerate(orgData) if i % 2 == 0]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
data = [ ("C20H20O3", 308.371) , ("C22H20O2", 316.393),("C24H40N4O2", 416.6),("C14H25N5O3", 311.38),("C15H20O2", 232.3181)]

for (formula, mw) in data:
    print( f"The molecular weight of {formula} is {mw}")

# %%
# singleton = (1,) # noticed trailing comma!!! 
s =(1)
print(s)
print(type(s))
q =(1,)
print(q)
print(type(q))

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# zipping lists together
names=["Ben", "Chen", "Jane"]
gender = ["M", "M", "F"]
list(zip(names, gender))

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
nobel_prize_winners = {
(1979, "physics"): ["Glashow", "Salam", "Weinberg"],
(1962, "chemistry"): ["Hodgkin"],
(1984, "biology"): ["McClintock"],
}

# %%
nobel_prize_winners[(1962, "chemistry")]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Hash tables, "associative arrays"
d = {"duck": "eend", "water": "water", "back": "rug"}

# Lookup:
d["duck"]
try:
    d["rug"] # raises KeyError exception
except:
    print("Cannot find rug")          
  
# Delete, insert, overwrite:
del d["water"]     # {"duck": "eend", "back": "rug"}
d["back"] = "rug"  # {"duck": "eend", "back": "rug"}
d["duck"] = "duik" # {"duck": "duik", "back": "rug"}
print(d)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a=[1,2,3]
b =[]
for item in a:
        b.append(item)
a.append(4)
print(b) # what is the value of b

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def gcd(a, b):
    "greatest common divisor"
    while a != 0:
        a, b = b%a, a    # parallel assignment
    return b

# %%
list.append?

# %%
gcd(12, 20)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Stack:
    "A well-known data structure…"
    def __init__(self):         # constructor
        self.items = []
    def push(self, x):
        self.items.append(x)	# the sky is the limit
    def pop(self):
        x = self.items[-1]		# what happens if it’s empty?
        del self.items[-1]
        return x
    def empty(self):
        return len(self.items) == 0	# Boolean result

# %%
x = Stack()

# %%
x.push("Apple")

# %%
x.push("Orange")

# %%
x.pop()

# %%
print(x)

# %%
x.items

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#To create an instance, simply call the class object:
x = Stack()	# no 'new' operator!

#To use methods of the instance, call using dot notation:
x.empty()
x.push(1)
x.empty()
x.push("hello")	# [1, "hello"]
x.pop()         # -> "hello"	# [1]

x.items		# -> [1]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class FancyStack(Stack):
    "stack with added ability to inspect inferior stack items"

    def peek(self, n):
        "peek(0) returns top; peek(-1) returns item below that; etc."
        size = len(self.items)
        assert 0 <= n < size			# test precondition
        return self.items[size-1-n]

# %%
class LimitedStack(FancyStack):
    "fancy stack with limit on stack size"

    def __init__(self, limit):
        self.limit = limit
        FancyStack.__init__(self)		# base class constructor

    def push(self, x):
        assert len(self.items) < self.limit
        FancyStack.push(self, x)		# "super" method call

# %%
ls = LimitedStack(5)

# %%
ls.push("e")
ls.items

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def foo(x):
    return 1/x

def bar(x):
    try:
        print (foo(x))
    except ZeroDivisionError:
        print ("Can’t divide by zero")
    except:
        print(e)

bar("apple")

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
try:
    f = open("space1.txt")

    print(f.readline())
finally:
    print("I did it")
    f.close()	# always executed
print ("OK")	# executed on success only

# %% [markdown]
# ![image.png](attachment:image.png)
